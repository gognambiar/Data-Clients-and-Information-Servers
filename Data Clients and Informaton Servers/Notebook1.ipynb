# %%
library(twitteR)
setup_twitter_oauth("","","","")#Enter your OAuth creds here
# Out:
# [1] "Using direct authentication"

# %%
tweets <- searchTwitter('buffalobills', n=100)
head(tweets)
# Out:
# [[1]]
# [1] "iBleedPhilly: @Italianphinfan @CutonDime25 @buffalobills wish it can happen"
#
# [[2]]
# [1] "bpsmiteye: Don't know how to create a poll but @buffalobills tickets or 35 shows @townballroom or @WaitingRoomBflo"
#
# [[3]]
# [1] "BuffaloBills1v: #Workout #fitblr Are Small Goals For Weight Loss The Next Big Thing? https://t.co/5NQuEfYZRT #BuffaloBills #Fit"
#
# [[4]]
# [1] "BuffaloBills1v: #BuffaloBills #Card Fred Jackson / C.J. Spiller Buffalo Bills 2013 Spectra Dual #NFL Game #Jersey…… https://t.co/KCPsXr9zS0"
#
# [[5]]
# [1] "MattStriegel: RT @NDSUfootball: Ramon Humber tied for the @buffalobills team lead with 12 special teams tackles in 2016. #ProBison https://t.co/9lkK6TAb2c"
#
# [[6]]
# [1] "kboncal79: RT @buffalobills: The Life of Thurman Thomas is hitting the stage!\n\nA fundraiser musical performance premieres in June: https://t.co/YIGt1j…"

# %%
head(strip_retweets(tweets, strip_manual=TRUE, strip_mt=TRUE))
# Out:
# [[1]]
# [1] "iBleedPhilly: @Italianphinfan @CutonDime25 @buffalobills wish it can happen"
#
# [[2]]
# [1] "bpsmiteye: Don't know how to create a poll but @buffalobills tickets or 35 shows @townballroom or @WaitingRoomBflo"
#
# [[3]]
# [1] "BuffaloBills1v: #Workout #fitblr Are Small Goals For Weight Loss The Next Big Thing? https://t.co/5NQuEfYZRT #BuffaloBills #Fit"
#
# [[4]]
# [1] "BuffaloBills1v: #BuffaloBills #Card Fred Jackson / C.J. Spiller Buffalo Bills 2013 Spectra Dual #NFL Game #Jersey…… https://t.co/KCPsXr9zS0"
#
# [[5]]
# [1] "BillsNewsNow: #GoBills #BillsMafia #Forum Alex Marvez is trashing the Bills on NFL Network radio https://t.co/0kZnuzYlpG"
#
# [[6]]
# [1] "BuffaloBills1v: #BuffaloBills #Card 2015 #Topps SUPER BOWL XXVII COIN CARD DALLAS COWBOYS v BUFFALO BILLS https://t.co/GvsGn34nTl… https://t.co/iTjdLI34yW"

# %%
crantastic <- getUser('@buffalobills')
crantastic$getDescription()
# Out:
# [1] "Official Twitter of the Buffalo Bills. Follow: @KimPegula @RussBrandon @ChrisBrownBills @JohnMurphyShow @BuffaloBillsPR @BillsEquipment @LaurenHall @NewEraField"

# %%
crantastic$getFollowersCount()
crantastic$getFriends(n=5)
# Out:
# [1] 677966
# $`174701263`
# [1] "CoachEgorugwu"
#
# $`1226212088`
# [1] "BillTeerlinck"
#
# $`392343915`
# [1] "s_gary7"
#
# $`796109748512968704`
# [1] "WCHOBisMoving"

# %%
crantastic$getFavorites(n=5)
# Out:
# [[1]]
# [1] "CRose2u: @buffalobills @Dajones19 @JohnMurphyShow You are an inspiration Donald!!!  Glad to hear your story and your success #BillsMafia\xed\xa0\xbd\xed\xb1\x8f"
#
# [[2]]
# [1] "thejared85: @buffalobills @Dajones19 this is awesome ! Congratulations"
#
# [[3]]
# [1] "TheRealBomasuto: @buffalobills as a kidney donor myself, it's amazing to see this man get a kidney from his father. I gave mine to my dad."
#
# [[4]]
# [1] "drtory: @buffalobills @thurmanthomas um a musical about my favourite RB of all time? Yes please!"
#
# [[5]]
# [1] "brandonspikes55: Love seeing kids still playing outside. Today I got to join em’ in some neighborhood ball. #coolkids #offseasonfun \xed\xa0\xbc\xed\xbf\x80 https://t.co/ViDS1QNv8b"

# %%
df <- twListToDF(tweets)
head(df)
# Out:
#   text
# 1 @Italianphinfan @CutonDime25 @buffalobills wish it can happen
# 2 Don't know how to create a poll but @buffalobills tickets or 35 shows @townballroom or @WaitingRoomBflo
# 3 #Workout #fitblr Are Small Goals For Weight Loss The Next Big Thing? https://t.co/5NQuEfYZRT #BuffaloBills #Fit
# 4 #BuffaloBills #Card Fred Jackson / C.J. Spiller Buffalo Bills 2013 Spectra Dual #NFL Game #Jersey…… https://t.co/KCPsXr9zS0
# 5 RT @NDSUfootball: Ramon Humber tied for the @buffalobills team lead with 12 special teams tackles in 2016. #ProBison https://t.co/9lkK6TAb2c
# 6 RT @buffalobills: The Life of Thurman Thomas is hitting the stage!\n\nA fundraiser musical performance premieres in June: https://t.co/YIGt1j…
#   favorited favoriteCount replyToSN      created             truncated
# 1 FALSE     0             Italianphinfan 2017-02-17 02:47:22 FALSE
# 2 FALSE     1             NA             2017-02-17 02:44:09 FALSE
# 3 FALSE     0             NA             2017-02-17 02:42:52 FALSE
# 4 FALSE     0             NA             2017-02-17 02:42:51  TRUE
# 5 FALSE     0             NA             2017-02-17 02:35:34 FALSE
# 6 FALSE     0             NA             2017-02-17 02:32:44 FALSE
#   replyToSID         id                 replyToUID
# 1 832410099394215937 832421148470235140 4136500036
# 2 NA                 832420340160724992 NA
# 3 NA                 832420018553921536 NA
# 4 NA                 832420014036643840 NA
# 5 NA                 832418182321303552 NA
# 6 NA                 832417465833500672 NA
#   statusSource
# 1 <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3 <a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>
# 4 <a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>
# 5 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 6 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#   screenName     retweetCount isRetweet retweeted longitude latitude
# 1 iBleedPhilly    0           FALSE     FALSE     NA        NA
# 2 bpsmiteye       0           FALSE     FALSE     NA        NA
# 3 BuffaloBills1v  0           FALSE     FALSE     NA        NA
# 4 BuffaloBills1v  0           FALSE     FALSE     NA        NA
# 5 MattStriegel    4            TRUE     FALSE     NA        NA
# 6 kboncal79      27            TRUE     FALSE     NA        NA

# %%
sql_lite_file = tempfile()
register_sqlite_backend(sql_lite_file)
store_tweets_db(tweets)
from_db = load_tweets_db()
head(from_db)
# Out:
# Loading required namespace: RSQLite
# [1] TRUE
# [[1]]
# [1] "iBleedPhilly: @Italianphinfan @CutonDime25 @buffalobills wish it can happen"
#
# [[2]]
# [1] "bpsmiteye: Don't know how to create a poll but @buffalobills tickets or 35 shows @townballroom or @WaitingRoomBflo"
#
# [[3]]
# [1] "BuffaloBills1v: #Workout #fitblr Are Small Goals For Weight Loss The Next Big Thing? https://t.co/5NQuEfYZRT #BuffaloBills #Fit"
#
# [[4]]
# [1] "BuffaloBills1v: #BuffaloBills #Card Fred Jackson / C.J. Spiller Buffalo Bills 2013 Spectra Dual #NFL Game #Jersey…… https://t.co/KCPsXr9zS0"
#
# [[5]]
# [1] "MattStriegel: RT @NDSUfootball: Ramon Humber tied for the @buffalobills team lead with 12 special teams tackles in 2016. #ProBison https://t.co/9lkK6TAb2c"
#
# [[6]]
# [1] "kboncal79: RT @buffalobills: The Life of Thurman Thomas is hitting the stage!\n\nA fundraiser musical performance premieres in June: https://t.co/YIGt1j…"

# %%
cran_tweets <- userTimeline('cranatic')
cran_tweets[1:5]
cran_tweets_large <- userTimeline('cranatic', n=100)
length(cran_tweets_large)
# Out:
# [[1]]
# [1] "cranatic: Update: Bchron, BoolNet, caribou, CePa, fmri, HTSCluster, isa2, lessR, lgcp, spatstat. http://t.co/skyrajMA #rstats"
#
# [[2]]
# [1] "cranatic: New: extrafont, extrafontdb, Rttf2pt1, x12GUI. http://t.co/skyrajMA #rstats"
#
# [[3]]
# [1] "cranatic: Update: drc, RcmdrPlugin.survival, rrcov, spls. http://t.co/eEoXNifB #rstats"
#
# [[4]]
# [1] "cranatic: New: hzar. http://t.co/eEoXNifB #rstats"
#
# [[5]]
# [1] "cranatic: Update: directlabels, forensim, gdata, gWidgetstcltk, gWidgetsWWW, harvestr, rrlda, Rz, Sim.DiffProc, ... http://t.co/9JEe7K91 #rstats"
# [1] 100

# %%
avail_trends = availableTrendLocations()
head(avail_trends)
# Out:
#   name      country woeid
# 1 Worldwide         1
# 2 Winnipeg  Canada  2972
# 3 Ottawa    Canada  3369
# 4 Quebec    Canada  3444
# 5 Montreal  Canada  3534
# 6 Toronto   Canada  4118

# %%
trends = getTrends(2367105)
head(trends)
# Out:
#   name                   url
# 1 #TrumpPressConference  http://twitter.com/search?q=%23TrumpPressConference
# 2 Brad Stevens           http://twitter.com/search?q=%22Brad+Stevens%22
# 3 #ADayWithoutImmigrants http://twitter.com/search?q=%23ADayWithoutImmigrants
# 4 #AAASmtg               http://twitter.com/search?q=%23AAASmtg
# 5 #hurtbae               http://twitter.com/search?q=%23hurtbae
# 6 Hanley Ramirez         http://twitter.com/search?q=%22Hanley+Ramirez%22
#   query                    woeid
# 1 %23TrumpPressConference  2367105
# 2 %22Brad+Stevens%22       2367105
# 3 %23ADayWithoutImmigrants 2367105
# 4 %23AAASmtg               2367105
# 5 %23hurtbae               2367105
# 6 %22Hanley+Ramirez%22     2367105

# %%
r_tweets <- searchTwitter("#falcons", n=300)
sources <- sapply(r_tweets, function(x) x$getStatusSource())
sources <- gsub("</a>", "", sources)
sources <- strsplit(sources, ">")
sources <- sapply(sources, function(x) ifelse(length(x) > 1, x[2], x[1]))
source_table = table(sources)
pie(source_table[source_table > 10])
# Out:
# plot without title
